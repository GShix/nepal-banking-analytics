# %%
import pandas as pd
df = pd.read_csv('../data/dirty/banking_data_dirty.csv')
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Customer_ID            1050 non-null   str
#  1   Customer_Name          1050 non-null   str
#  2   Gender                 1050 non-null   str
#  3   Age                    1050 non-null   int64
#  4   City                   1050 non-null   str
#  5   Province               1050 non-null   str
#  6   Occupation             1038 non-null   str
#  7   Education_Level        1020 non-null   str
#  8   Marital_Status         1050 non-null   str
#  9   Account_Number         1050 non-null   str
#  10  Account_Type           1050 non-null   str
#  11  Account_Open_Date      1050 non-null   str
#  12  Branch_Name            1050 non-null   str
#  13  Monthly_Income         1050 non-null   str
#  14  Credit_Score           1050 non-null   int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(50)
